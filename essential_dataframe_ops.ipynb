# %% [markdown]
# # Chapter 2 – Essential DataFrame Operations
#
# This notebook accompanies Chapter 2 of the *Cookbook for Pandas*, demonstrating core DataFrame operations using a synthetic healthcare dataset.

# %%
# Imports
import pandas as pd

# Load dataset
df = pd.read_csv('data/health_data.csv', parse_dates=['AdmissionDate', 'DischargeDate'])
df.head()
# Out:
#    PatientID              Name  Age   Department Diagnosis AdmissionDate  \
# 0       1001      Norma Fisher   62     Oncology  Fracture    2023-01-28
# 1       1002    Jorge Sullivan   65     Oncology     Fever    2023-01-15
# 2       1003   Elizabeth Woods   82   Cardiology    Stroke    2023-02-11
# 3       1004      Susan Wagner   85  Orthopedics    Stroke    2023-02-28
# 4       1005  Peter Montgomery   85   Pediatrics     Fever    2023-01-02
#
#   DischargeDate  BloodPressure  HeartRate
# 0    2023-01-06            110        108
# 1    2023-02-07            172        107
# 2    2023-03-05            158         70
# 3    2023-02-15            112        105
# 4    2023-02-04            173        100

# %% [markdown]
# ## Accessing and Modifying DataFrames

# %%
# Filter cardiology patients
df[df['Department'] == 'Cardiology']

# Update diagnosis for a specific patient
df.loc[df['PatientID'] == 1004, 'Diagnosis'] = 'Lung Cancer'
df.loc[df['PatientID'] == 1004]
# Out:
#    PatientID          Name  Age   Department    Diagnosis AdmissionDate  \
# 3       1004  Susan Wagner   85  Orthopedics  Lung Cancer    2023-02-28
#
#   DischargeDate  BloodPressure  HeartRate
# 3    2023-02-15            112        105

# %% [markdown]
# ## Adding, Dropping, and Renaming Columns

# %%
# Add a new 'RiskLevel' column
def calculate_risk(row):
    if row['BloodPressure'] > 140 or row['HeartRate'] > 100:
        return 'High'
    return 'Normal'

df['RiskLevel'] = df.apply(calculate_risk, axis=1)

# Drop 'Name' column for privacy
df = df.drop(columns='Name')

# Rename 'Diagnosis' to 'MedicalCondition'
df = df.rename(columns={'Diagnosis': 'MedicalCondition'})
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 10
#       7 df['RiskLevel'] = df.apply(calculate_risk, axis=1)
#       9 # Drop 'Name' column for privacy
# ---> 10 df = df.drop(columns='Name')
#      12 # Rename 'Diagnosis' to 'MedicalCondition'
#      13 df = df.rename(columns={'Diagnosis': 'MedicalCondition'})
#
# File c:\Users\Poornachand\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:5344, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5196 def drop(
#    5197     self,
#    5198     labels: IndexLabel | None = None,
#    (...)
#    5205     errors: IgnoreRaise = "raise",
#    5206 ) -> DataFrame | None:
#    5207     """
#    5208     Drop specified labels from rows or columns.
#    5209
#    (...)
#    5342             weight  1.0     0.8
#    5343     """
# -> 5344     return super().drop(
#    5345         labels=labels,
#    5346         axis=axis,
#    5347         index=index,
#    5348         columns=columns,
#    5349         level=level,
#    5350         inplace=inplace,
#    5351         errors=errors,
#    5352     )
#
# File c:\Users\Poornachand\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:4711, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4709 for axis, labels in axes.items():
#    4710     if labels is not None:
# -> 4711         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4713 if inplace:
#    4714     self._update_inplace(obj)
#
# File c:\Users\Poornachand\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:4753, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4751         new_axis = axis.drop(labels, level=level, errors=errors)
#    4752     else:
# -> 4753         new_axis = axis.drop(labels, errors=errors)
#    4754     indexer = axis.get_indexer(new_axis)
#    4756 # Case for non-unique axis
#    4757 else:
#
# File c:\Users\Poornachand\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:7000, in Index.drop(self, labels, errors)
#    6998 if mask.any():
#    6999     if errors != "ignore":
# -> 7000         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7001     indexer = indexer[~mask]
#    7002 return self.delete(indexer)
#
# KeyError: "['Name'] not found in axis"

# %% [markdown]
# ## Sorting and Reindexing

# %%
# Sort by admission date
df_sorted = df.sort_values(by='AdmissionDate')
df_sorted[['PatientID', 'AdmissionDate']].head()
# Out:
#     PatientID AdmissionDate
# 16       1017    2023-01-01
# 93       1094    2023-01-02
# 4        1005    2023-01-02
# 11       1012    2023-01-03
# 27       1028    2023-01-03

# %% [markdown]
# ## Applying Functions with apply(), map(), and applymap()

# %%
# Calculate length of stay
df['LengthOfStay'] = (df['DischargeDate'] - df['AdmissionDate']).dt.days

# Simplify medical condition
df['MedicalCondition'] = df['MedicalCondition'].map(lambda x: 'Other' if x not in ['Stroke', 'Hypertension'] else x)
df[['PatientID', 'LengthOfStay', 'MedicalCondition']].head()
# Out:
#    PatientID  LengthOfStay MedicalCondition
# 0       1001           -22            Other
# 1       1002            23            Other
# 2       1003            22           Stroke
# 3       1004           -13            Other
# 4       1005            33            Other

# %% [markdown]
# ## Handling Missing Data

# %%
# Introduce some missing values for demo
import numpy as np
df.loc[5:10, 'BloodPressure'] = np.nan

# Fill missing BloodPressure values with mean per department
df['BloodPressure'] = df.groupby('Department')['BloodPressure'].transform(lambda x: x.fillna(x.mean()))
df.head(12)
# Out:
#     PatientID  Age   Department MedicalCondition AdmissionDate DischargeDate  \
# 0        1001   62     Oncology            Other    2023-01-28    2023-01-06
# 1        1002   65     Oncology            Other    2023-01-15    2023-02-07
# 2        1003   82   Cardiology           Stroke    2023-02-11    2023-03-05
# 3        1004   85  Orthopedics            Other    2023-02-28    2023-02-15
# 4        1005   85   Pediatrics            Other    2023-01-02    2023-02-04
# 5        1006   27     Oncology            Other    2023-02-06    2023-01-14
# 6        1007   39     Oncology            Other    2023-01-11    2023-01-13
# 7        1008   54  Orthopedics            Other    2023-01-23    2023-02-26
# 8        1009   88     Oncology            Other    2023-02-13    2023-02-09
# 9        1010   30  Orthopedics            Other    2023-02-10    2023-01-31
# 10       1011   76   Pediatrics            Other    2023-01-12    2023-01-05
# 11       1012   83    Neurology     Hypertension    2023-01-03    2023-01-30
#
#     BloodPressure  HeartRate RiskLevel  LengthOfStay
# 0      110.000000        108      High           -22
# 1      172.000000        107      High            23
# 2      158.000000         70      High            22
# 3      112.000000        105      High           -13
# 4      173.000000        100      High            33
# 5      144.071429         90    Normal           -23
# 6      144.071429         87      High             2
# 7      133.888889        103      High            34
# 8      144.071429         91    Normal            -4
# 9      133.888889         80    Normal           -10
# 10     139.400000         66    Normal            -7
# 11      98.000000         69    Normal            27

# %% [markdown]
# ## Copying and Modifying DataFrames

# %%
# Create a copy for simulation
df_sim = df.copy()
df_sim['Age'] += 5
df_sim.head()
# Out:
#    PatientID  Age   Department MedicalCondition AdmissionDate DischargeDate  \
# 0       1001   67     Oncology            Other    2023-01-28    2023-01-06
# 1       1002   70     Oncology            Other    2023-01-15    2023-02-07
# 2       1003   87   Cardiology           Stroke    2023-02-11    2023-03-05
# 3       1004   90  Orthopedics            Other    2023-02-28    2023-02-15
# 4       1005   90   Pediatrics            Other    2023-01-02    2023-02-04
#
#    BloodPressure  HeartRate RiskLevel  LengthOfStay
# 0          110.0        108      High           -22
# 1          172.0        107      High            23
# 2          158.0         70      High            22
# 3          112.0        105      High           -13
# 4          173.0        100      High            33

# %% [markdown]
# ## Recipes

# %%
# Recipe: Flag Critical Patients
df['CriticalFlag'] = df.apply(lambda row: row['BloodPressure'] > 140 or row['HeartRate'] > 100, axis=1)
df[['PatientID', 'BloodPressure', 'HeartRate', 'CriticalFlag']].head()
# Out:
#    PatientID  BloodPressure  HeartRate  CriticalFlag
# 0       1001          110.0        108          True
# 1       1002          172.0        107          True
# 2       1003          158.0         70          True
# 3       1004          112.0        105          True
# 4       1005          173.0        100          True
